# %% [markdown]
# In this notebook, we will be diving into the world of web scraping using the rvest library.
#
# Web scraping is a technique for extracting information from websites. The rvest library is a powerful tool for web scraping in R, providing a wide range of functions for working with HTML and XML documents.
#
# First, let's start by installing and loading the necessary library: rvest.

# %%
library("rvest")

# %% [markdown]
# Now, let's use the read_html function to read the HTML of a website. We will be using the example of scraping data from "Wikipedia", you can do this by running the following code:

# %%
# Read the HTML of the website
url <- "https://www.wikipedia.org/"
html <- read_html(url)

# %% [markdown]
# The read_html function takes one argument: the URL of the website to scrape.
#
# Now, we can use the html_nodes function to select specific elements of the HTML document. Let's select all of the anchor tags on the page, we can do this using the following code:

# %%
# Select all of the anchor tags
anchors <- html_nodes(html, "a")

# %%
anchors
# Out:
# {xml_nodeset (334)}
#  [1] <a id="js-link-box-en" href="//en.wikipedia.org/" title="English — Wikip ...
#  [2] <a id="js-link-box-ru" href="//ru.wikipedia.org/" title="Russkiy — Викип ...
#  [3] <a id="js-link-box-es" href="//es.wikipedia.org/" title="Español — Wikip ...
#  [4] <a id="js-link-box-ja" href="//ja.wikipedia.org/" title="Nihongo — ウィキペデ ...
#  [5] <a id="js-link-box-de" href="//de.wikipedia.org/" title="Deutsch — Wikip ...
#  [6] <a id="js-link-box-fr" href="//fr.wikipedia.org/" title="français — Wiki ...
#  [7] <a id="js-link-box-it" href="//it.wikipedia.org/" title="Italiano — Wiki ...
#  [8] <a id="js-link-box-zh" href="//zh.wikipedia.org/" title="Zhōngwén — 维基百科 ...
#  [9] <a id="js-link-box-fa" href="//fa.wikipedia.org/" title="Fārsi — ویکی‌پد ...
# [10] <a id="js-link-box-pt" href="//pt.wikipedia.org/" title="Português — Wik ...
# [11] <a href="//pl.wikipedia.org/" lang="pl">Polski</a>
# [12] <a href="//ar.wikipedia.org/" lang="ar" title="Al-ʿArabīyah"><bdi dir="r ...
# [13] <a href="//de.wikipedia.org/" lang="de">Deutsch</a>
# [14] <a href="//en.wikipedia.org/" lang="en" title="English">English</a>
# [15] <a href="//es.wikipedia.org/" lang="es">Español</a>
# [16] <a href="//fr.wikipedia.org/" lang="fr" title="français">Français</a>
# [17] <a href="//it.wikipedia.org/" lang="it">Italiano</a>
# [18] <a href="//arz.wikipedia.org/" lang="arz" title="Maṣrī"><bdi dir="rtl">م ...
# [19] <a href="//nl.wikipedia.org/" lang="nl">Nederlands</a>
# [20] <a href="//ja.wikipedia.org/" lang="ja" title="Nihongo">日本語</a>
# ...

# %% [markdown]
# The html_nodes function takes two arguments: the HTML document and a CSS selector for the elements to select.
#
# We can use the html_text function to extract the text from the selected elements. Let's extract the text from the anchor tags, we can do this using the following code:

# %%
# Extract the text from the anchor tags
anchor_text <- html_text(anchors)

# %%
anchor_text
# Out:
#   [1] "\nEnglish\n6 638 000+articles\n"
#   [2] "\nРусский\n1 905 000+статей\n"
#   [3] "\nEspañol\n1 851 000+artículos\n"
#   [4] "\n日本語\n1 368 000+記事\n"
#   [5] "\nDeutsch\n2 788 000+Artikel\n"
#   [6] "\nFrançais\n2 510 000+articles\n"
#   [7] "\nItaliano\n1 805 000+voci\n"
#   [8] "\n中文\n1 344 000+条目 / 條目\n"
#   [9] "\nفارسی\n957 000+مقاله\n"
#  [10] "\nPortuguês\n1 103 000+artigos\n"
#  [11] "Polski"
#  [12] "العربية"
#  [13] "Deutsch"
#  [14] "English"
#  [15] "Español"
#  [16] "Français"
#  [17] "Italiano"
#  [18] "مصرى"
#  [19] "Nederlands"
#  [20] "日本語"
#  [21] "Português"
#  [22] "Sinugboanong Binisaya"
#  [23] "Svenska"
#  [24] "Українська"
#  [25] "Tiếng Việt"
#  [26] "Winaray"
#  [27] "中文"
#  [28] "Русский"
#  [29] "Afrikaans"
#  [30] "Asturianu"
#  [31] "Azərbaycanca"
#  [32] "Български"
#  [33] "Bân-lâm-gú / Hō-ló-oē"
#  [34] "বাংলা"
#  [35] "Беларуская"
#  [36] "Català"
#  [37] "Čeština"
#  [38] "Cymraeg"
#  [39] "Dansk"
#  [40] "Eesti"
#  [41] "Ελληνικά"
#  [42] "Esperanto"
#  [43] "Euskara"
#  [44] "فارسی"
#  [45] "Galego"
#  [46] "한국어"
#  [47] "हिन्दी"
#  [48] "Hrvatski"
#  [49] "Bahasa Indonesia"
#  [50] "עברית"
#  [51] "ქართული"
#  [52] "Latina"
#  [53] "Latviešu"
#  [54] "Lietuvių"
#  [55] "Magyar"
#  [56] "Македонски"
#  [57] "Bahasa Melayu"
#  [58] "Bahaso Minangkabau"
#  [59] "bokmål"
#  [60] "nynorsk"
#  [61] "Нохчийн"
#  [62] "Oʻzbekcha / Ўзбекча"
#  [63] "Қазақша / Qazaqşa / قازاقشا"
#  [64] "Română"
#  [65] "Simple English"
#  [66] "Slovenčina"
#  [67] "Slovenščina"
#  [68] "Српски / Srpski"
#  [69] "Srpskohrvatski / Српскохрватски"
#  [70] "Suomi"
#  [71] "தமிழ்"
#  [72] "Татарча / Tatarça"
#  [73] "ภาษาไทย"
#  [74] "Тоҷикӣ"
#  [75] "تۆرکجه"
#  [76] "Türkçe"
#  [77] "اردو"
#  [78] "粵語"
#  [79] "Հայերեն"
#  [80] "မြန်မာဘာသာ"
#  [81] "Bahsa Acèh"
#  [82] "Alemannisch"
#  [83] "አማርኛ"
#  [84] "Aragonés"
#  [85] "Արեւմտահայերէն"
#  [86] "Basa Bali"
#  [87] "Bahasa Banjar"
#  [88] "Basa Banyumasan"
#  [89] "Башҡортса"
#  [90] "Беларуская (Тарашкевіца)"
#  [91] "Bikol Central"
#  [92] "বিষ্ণুপ্রিয়া মণিপুরী"
#  [93] "Boarisch"
#  [94] "Bosanski"
#  [95] "Brezhoneg"
#  [96] "Чӑвашла"
#  [97] "Diné Bizaad"
#  [98] "Emigliàn–Rumagnòl"
#  [99] "Fiji Hindi"
# [100] "Føroyskt"
# [101] "Frysk"
# [102] "Gaeilge"
# [103] "Gàidhlig"
# [104] "ગુજરાતી"
# [105] "Hak-kâ-ngî / 客家語"
# [106] "Hausa"
# [107] "Hornjoserbsce"
# [108] "Ido"
# [109] "Igbo"
# [110] "Ilokano"
# [111] "Interlingua"
# [112] "Interlingue"
# [113] "Ирон"
# [114] "Íslenska"
# [115] "Jawa"
# [116] "ಕನ್ನಡ"
# [117] "ភាសាខ្មែរ"
# [118] "Kreyòl Ayisyen"
# [119] "Kurdî / كوردی"
# [120] "کوردیی ناوەندی"
# [121] "Кыргызча"
# [122] "Кырык мары"
# [123] "Lëtzebuergesch"
# [124] "Lìgure"
# [125] "Limburgs"
# [126] "Lombard"
# [127] "मैथिली"
# [128] "Malagasy"
# [129] "മലയാളം"
# [130] "文言"
# [131] "मराठी"
# [132] "მარგალური"
# [133] "مازِرونی"
# [134] "Mìng-dĕ̤ng-ngṳ̄ / 閩東語"
# [135] "Монгол"
# [136] "Napulitano"
# [137] "नेपाल भाषा"
# [138] "नेपाली"
# [139] "Nordfriisk"
# [140] "Occitan"
# [141] "Олык марий"
# [142] "ଓଡି଼ଆ"
# [143] "অসমীযা়"
# [144] "ਪੰਜਾਬੀ (ਗੁਰਮੁਖੀ)"
# [145] "پنجابی (شاہ مکھی)"
# [146] "پښتو"
# [147] "Piemontèis"
# [148] "Plattdüütsch"
# [149] "Qırımtatarca"
# [150] "Runa Simi"
# [151] "संस्कृतम्"
# [152] "Саха Тыла"
# [153] "Scots"
# [154] "ChiShona"
# [155] "Shqip"
# [156] "Sicilianu"
# [157] "සිංහල"
# [158] "سنڌي"
# [159] "Ślůnski"
# [160] "Basa Sunda"
# [161] "Kiswahili"
# [162] "Tagalog"
# [163] "ၽႃႇသႃႇတႆး"
# [164] "తెలుగు"
# [165] "ᨅᨔ ᨕᨙᨁᨗ / Basa Ugi"
# [166] "Vèneto"
# [167] "Volapük"
# [168] "Walon"
# [169] "吴语"
# [170] "ייִדיש"
# [171] "Yorùbá"
# [172] "Zazaki"
# [173] "Žemaitėška"
# [174] "isiZulu"
# [175] "Dzhudezmo / לאדינו"
# [176] "Адыгэбзэ"
# [177] "Ænglisc"
# [178] "Anarâškielâ"
# [179] "अंगिका"
# [180] "аԥсшәа"
# [181] "Armãneashce"
# [182] "Arpitan"
# [183] "ܐܬܘܪܝܐ"
# [184] "Avañe’ẽ"
# [185] "Авар"
# [186] "Aymar"
# [187] "भोजपुरी"
# [188] "Bislama"
# [189] "བོད་ཡིག"
# [190] "Буряад"
# [191] "Chavacano de Zamboanga"
# [192] "Chichewa"
# [193] "Corsu"
# [194] "Vahcuengh / 話僮"
# [195] "Dagbanli"
# [196] "الدارجة"
# [197] "Davvisámegiella"
# [198] "Deitsch"
# [199] "ދިވެހިބަސް"
# [200] "Dolnoserbski"
# [201] "Эрзянь"
# [202] "Estremeñu"
# [203] "Furlan"
# [204] "Gaelg"
# [205] "Gagauz"
# [206] "ГӀалгӀай"
# [207] "Gĩkũyũ"
# [208] "گیلکی"
# [209] "赣语 / 贛語"
# [210] "Gungbe"
# [211] "Хальмг"
# [212] "ʻŌlelo Hawaiʻi"
# [213] "Ikinyarwanda"
# [214] "Kabɩyɛ"
# [215] "Kapampangan"
# [216] "Kaszëbsczi"
# [217] "Kernewek"
# [218] "Коми"
# [219] "Перем коми"
# [220] "Kongo"
# [221] "कोंकणी / Konknni"
# [222] "كٲشُر"
# [223] "Kriyòl Gwiyannen"
# [224] "ພາສາລາວ"
# [225] "Лакку"
# [226] "Latgaļu"
# [227] "Лезги"
# [228] "Li Niha"
# [229] "Lingála"
# [230] "lojban"
# [231] "Luganda"
# [232] "Madhurâ"
# [233] "Malti"
# [234] "Māori"
# [235] "Twi"
# [236] "Mirandés"
# [237] "Мокшень"
# [238] "ဘာသာ မန်"
# [239] "ߒߞߏ"
# [240] "Na Vosa Vaka-Viti"
# [241] "Nāhuatlahtōlli"
# [242] "Dorerin Naoero"
# [243] "Nedersaksisch"
# [244] "Nouormand / Normaund"
# [245] "Novial"
# [246] "Afaan Oromoo"
# [247] "ပအိုဝ်ႏဘာႏသာႏ"
# [248] "पालि"
# [249] "Pangasinán"
# [250] "Papiamentu"
# [251] "Pfälzisch"
# [252] "Picard"
# [253] "Къарачай–малкъар"
# [254] "Qaraqalpaqsha"
# [255] "Ripoarisch"
# [256] "Rumantsch"
# [257] "Русиньскый"
# [258] "Gagana Sāmoa"
# [259] "ᱥᱟᱱᱛᱟᱲᱤ"
# [260] "سرائیکی"
# [261] "Sardu"
# [262] "Seediq"
# [263] "Seeltersk"
# [264] "Sesotho sa Leboa"
# [265] "Setswana"
# [266] "Словѣ́ньскъ / ⰔⰎⰑⰂⰡⰐⰠⰔⰍⰟ"
# [267] "Soomaaliga"
# [268] "Sranantongo"
# [269] "Taqbaylit"
# [270] "Tarandíne"
# [271] "Tetun"
# [272] "Tok Pisin"
# [273] "faka Tonga"
# [274] "ᏣᎳᎩ"
# [275] "chiTumbuka"
# [276] "Türkmençe"
# [277] "Тыва дыл"
# [278] "Удмурт"
# [279] "ئۇيغۇرچه"
# [280] "Vepsän"
# [281] "Võro"
# [282] "West-Vlams"
# [283] "Wolof"
# [284] "isiXhosa"
# [285] "Zeêuws"
# [286] "Reo tahiti"
# [287] "Akan"
# [288] "Bamanankan"
# [289] "Chamoru"
# [290] "Eʋegbe"
# [291] "Farefare"
# [292] "Fulfulde"
# [293] "𐌲𐌿𐍄𐌹𐍃𐌺"
# [294] "ᐃᓄᒃᑎᑐᑦ / Inuktitut"
# [295] "Iñupiak"
# [296] "Kalaallisut"
# [297] "Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ"
# [298] "Norfuk / Pitkern"
# [299] "Pangcah"
# [300] "pinayuanan"
# [301] "Ποντιακά"
# [302] "རྫོང་ཁ"
# [303] "romani čhib"
# [304] "Ikirundi"
# [305] "Sängö"
# [306] "Sesotho"
# [307] "SiSwati"
# [308] "ትግርኛ"
# [309] "Thuɔŋjäŋ"
# [310] "Tsėhesenėstsestotse"
# [311] "Xitsonga"
# [312] "Tyap"
# [313] "Tshivenḓa"
# [314] "Wayuunaiki"
# [315] "Other languages"
# [316] "\nYou can support our work with a donation.\n"
# [317] "\nDownload Wikipedia for Android or iOS\n"
# [318] "\nGoogle Play Store\n"
# [319] "\nApple App Store\n"
# [320] "\n\n\n\n\nCommons\nFreely usable photos & more\n\n"
# [321] "\n\n\n\n\nWikivoyage\nFree travel guide\n\n"
# [322] "\n\n\n\n\nWiktionary\nFree dictionary\n\n"
# [323] "\n\n\n\n\nWikibooks\nFree textbooks\n\n"
# [324] "\n\n\n\n\nWikinews\nFree news source\n\n"
# [325] "\n\n\n\n\nWikidata\nFree knowledge base\n\n"
# [326] "\n\n\n\n\nWikiversity\nFree course materials\n\n"
# [327] "\n\n\n\n\nWikiquote\nFree quote compendium\n\n"
# [328] "\n\n\n\n\nMediaWiki\nFree & open wiki application\n\n"
# [329] "\n\n\n\n\nWikisource\nFree library\n\n"
# [330] "\n\n\n\n\nWikispecies\nFree species directory\n\n"
# [331] "\n\n\n\n\nMeta-Wiki\nCommunity coordination & documentation\n\n"
# [332] "Creative Commons Attribution-ShareAlike License"
# [333] "Terms of Use"
# [334] "Privacy Policy"

# %% [markdown]
# The html_text function takes one argument: the selected elements.
#
# Now, we can use the html_attrs function to extract the attributes of the selected elements. Let's extract the href attribute of the anchor tags, we can do this using the following code:

# %%
# Extract the href attribute from the anchor tags
anchor_hrefs <- html_attrs(anchors)$href

# %% [markdown]
# The html_attrs function takes one argument: the selected elements.
#
# That's it! You've just seen some examples of how to use the rvest library for web scraping in R. The rvest library is a powerful tool for working with HTML and XML documents, providing a wide range of functions for selecting, extracting, and manipulating elements of a document. I hope you found this notebook helpful and you can start using the rvest library in your own projects.
